# %% [markdown]
# ## Recursively remove spaces from file names
#
# If you use this common command:
#
# ``` find ./ ...    | xargs grep  ... ```
#
# it will break on names consisting of several words separated by spaces, because it will try to treat each word as a separate file name. You can go around this problem using options to use ASCII NUL character instead of space to end (separate) the filenames
# ```
#   -print0 option in find,
#   -0      option in xargs
# ```
# for example:
#
# ``` find ./ -type f -print0 | xargs -0 ls -1 ```
#
# Or you can simply clean the names by substituting
# spaces by underscores using code below

# %%
import sys, os, glob, subprocess, time, datetime

# %%
# provide absolute path under which you want to clean out spaces from names

# MYDIR = "/some/path"

# ----------------------------------
HOME = os.environ['HOME']
MYDIR = HOME + "/"
print(MYDIR)
if not os.path.isdir(MYDIR):
    print("ERROR - no such directory")
# ----------------------------------
skip_list = [
    "/Users/levselector/Library",
    "/Users/levselector/Music/Music",
    "/Users/levselector/Pictures",
    "/Users/levselector/Movies"
]
# ----------------------------------
def print_date_time():
    print(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
# ----------------------------------
time1 = time.time()
# ----------------------------------
# Out:
# /Users/levselector/

# %%
# %%time
# Clean directories' names.
# We need to do it layer by layer.
# ----------------------------------
# So repeat this cell several times 
# until there is no output.
# ----------------------------------
print_date_time()
dirs = glob.glob(MYDIR+"/**/", recursive=True)
for mydir in dirs:
    # ------------------------------
    skip_flag = False
    for elem in skip_list:
        if elem in mydir:
            skip_flag = True
    if skip_flag:
        continue
    # ------------------------------
    if not os.path.isdir(mydir):
        continue
    if " " not in mydir:
        continue
    mydir2 = mydir.replace(" ","_")
    print(f"renaming: {mydir} => {mydir2}")
    os.rename(mydir, mydir2)
print("DONE")
# Out:
# 2021-03-08 11:53:43
# DONE
# CPU times: user 9.03 s, sys: 15.3 s, total: 24.3 s
# Wall time: 29.2 s

# %%
# %%time
# Now rename files to remove spaces.
# ----------------------------------
# Run it twice. 
# On second run there should be no output.
# ----------------------------------
print_date_time()
files = glob.glob(MYDIR+"/**", recursive=True)
for myfile in files:
    # ------------------------------
    skip_flag = False
    for elem in skip_list:
        if elem in myfile:
            skip_flag = True
    if skip_flag:
        continue
    # ------------------------------
    if not os.path.isfile(myfile):
        continue
    if " " not in myfile:
        continue
    myfile2 = myfile.replace(" ","_")
    print(f"renaming: {myfile} => {myfile2}")
    os.rename(myfile, myfile2)
print("DONE")
# Out:
# 2021-03-08 11:54:12
# DONE
# CPU times: user 45.6 s, sys: 47.9 s, total: 1min 33s
# Wall time: 1min 47s

# %%
# %%time
# Now rename files to remove quotes.
# Run it twice. On second run there should be no output.
print_date_time()
files = glob.glob(MYDIR+"/**", recursive=True)
for myfile in files:
    # ------------------------------
    skip_flag = False
    for elem in skip_list:
        if elem in myfile:
            skip_flag = True
    if skip_flag:
        continue
    # ------------------------------
    if not os.path.isfile(myfile):
        continue
    if "'" not in myfile:
        continue
    myfile2 = myfile.replace("'","_")
    print(f"renaming: {myfile} => {myfile2}")
    os.rename(myfile, myfile2)
print("DONE")
# Out:
# 2021-03-08 11:55:59
# DONE
# CPU times: user 46.3 s, sys: 49.5 s, total: 1min 35s
# Wall time: 1min 48s

# %%
# %%time
print_date_time()
# Now rename files to remove double quotes.
# Run it twice. On second run there should be no output.
files = glob.glob(MYDIR+"/**", recursive=True)
for myfile in files:
    # ------------------------------
    skip_flag = False
    for elem in skip_list:
        if elem in myfile:
            skip_flag = True
    if skip_flag:
        continue
    # ------------------------------
    if not os.path.isfile(myfile):
        continue
    if '"' not in myfile:
        continue
    myfile2 = myfile.replace('"',"_")
    print(f"renaming: {myfile} => {myfile2}")
    os.rename(myfile, myfile2)
print("DONE")
# Out:
# 2021-03-08 11:57:47
# DONE
# CPU times: user 46.4 s, sys: 48.5 s, total: 1min 34s
# Wall time: 1min 45s

# %%
# %%time
# Now rename files to remove "&" symbol
# Run it twice. On second run there should be no output.
print_date_time()
files = glob.glob(MYDIR+"/**", recursive=True)
for myfile in files:
    # ------------------------------
    skip_flag = False
    for elem in skip_list:
        if elem in myfile:
            skip_flag = True
    if skip_flag:
        continue
    # ------------------------------
    if not os.path.isfile(myfile):
        continue
    if '&' not in myfile:
        continue
    myfile2 = myfile.replace('&',"_")
    print(f"renaming: {myfile} => {myfile2}")
    os.rename(myfile, myfile2)
print("DONE")
# Out:
# 2021-03-08 11:59:32
# DONE
# CPU times: user 46.2 s, sys: 48 s, total: 1min 34s
# Wall time: 1min 47s

# %%
time2 = time.time()
elapsed = time2-time1
print(f"Elapsed seconds = {elapsed:.3f}")
# Out:
# Elapsed seconds = 457.615
