# %% [markdown]
# ## Recursively remove spaces from file names
#
# When you use this common command:
#
# ``` find ./ ...    | xargs grep  ... ```
#
# it will break on names consisting of several words separated by spaces,
# <br>because it will try to treat each word as a separate file name.
#
# You can go around this problem using options
# <br>to use ASCII NUL character instead of space
# <br>to end (separate) the filenames
# ```
#   -print0 option in find,
#   -0      option in xargs
# ```
# for example:
#
# ``` find ./ -type f -print0 | xargs -0 ls -1 ```
#
# Or you can simply run the code below
# <br>which will rename directories and files
# <br>by substituting spaces, quotes, etc.
# <br>by underscores

# %%
import sys, os, glob, subprocess, time, datetime

# %%
# provide absolute path under which 
# you want to clean out spaces from names
# MYDIR = "/some/path"
# ----------------------------------
HOME = os.environ['HOME']
MYDIR = HOME + "/"
print(MYDIR)
if not os.path.isdir(MYDIR):
    print("ERROR - no such directory")
# ----------------------------------
skip_list = [
    MYDIR+"Library",
    MYDIR+"Music/Music",
    MYDIR+"Pictures",
    MYDIR+"Movies",
    MYDIR+"docs_big/SOFT_big/misc_stuff/SiteSucker.app",
    MYDIR+"Documents/Splashtop Business/"
]
print(skip_list)
# ----------------------------------
def print_date_time():
    print(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
# ----------------------------------
time1 = time.time()
# ----------------------------------
# Out:
# /Users/levselector/
# ['/Users/levselector/Library', '/Users/levselector/Music/Music', '/Users/levselector/Pictures', '/Users/levselector/Movies', '/Users/levselector/docs_big/SOFT_big/misc_stuff/SiteSucker.app', '/Users/levselector/Documents/Splashtop Business/']

# %% [markdown]
# #### Clean directories' names layer by layer.
# #### Repeat next cell several times until there is no output.

# %%
# %%time
print_date_time()
print(f"Getting list of directories under {MYDIR} - takes some time")
dirs = glob.glob(MYDIR+"/**/", recursive=True)
print_date_time()
N = len(dirs)
print(f"found {N:,d} dirs")
for mydir in dirs:
    # ------------------------------
    skip_flag = False
    for elem in skip_list:
        if elem in mydir:
            skip_flag = True
    if skip_flag:
        continue
    # ------------------------------
    if not os.path.isdir(mydir):
        continue
    if " " not in mydir:
        continue
    mydir2 = mydir.replace(" ","_")
    print(f"renaming: {mydir} => {mydir2}")
    os.rename(mydir, mydir2)
print("DONE")
# Out:
# 2021-03-20 22:06:38
# Getting list of directories under /Users/levselector/ - takes some time
# 2021-03-20 22:07:06
# found 293,702 dirs
# DONE
# CPU times: user 8.96 s, sys: 15 s, total: 24 s
# Wall time: 29 s

# %% [markdown]
# #### Next we can rename files to remove spaces, quotes, double quotes, "&".

# %%
# ----------------------------------
def rename_if_needed(myfile):
    myfile2 = myfile[:]
    if " " in myfile:
        myfile2 = myfile2.replace(" ","_")
    if "'" in myfile:
        myfile2 = myfile2.replace("'","_")
    if '"' in myfile:
        myfile2 = myfile2.replace('"',"_")
    if '&' in myfile:
        myfile2 = myfile2.replace('&',"_")      
    if myfile2 != myfile:
        print(f"renaming: {myfile} => {myfile2}")
        os.rename(myfile, myfile2) 

# ----------------------------------
def in_skip_list(myfile):
    skip_flag = False
    for elem in skip_list:
        if elem in myfile:
            skip_flag = True
    return skip_flag

# %% [markdown]
# #### Run the next cell twice until there is no output

# %%
# %%time
print_date_time()
print(f"Getting list of files under {MYDIR} - takes some time")
files = glob.glob(MYDIR+"/**", recursive=True)
print_date_time()
N = len(files)
N_step = N//10
print(f"found {N:,d} files")
print(f"printing after every {N_step:,d} files")
for ii in range(N):
    if ((ii % N_step) == 0) and (ii > 0):
        print(f"processing file # {ii:,d} of {N:,d}")
    myfile = files[ii]
    if in_skip_list(myfile):
        continue
    if not os.path.isfile(myfile):
        continue
    rename_if_needed(myfile)
print_date_time()
print("DONE")
# Out:
# 2021-03-20 22:07:06
# Getting list of files under /Users/levselector/ - takes some time
# 2021-03-20 22:08:38
# found 2,581,359 files
# printing after every 258,135 files
# processing file # 258,135 of 2,581,359
# processing file # 516,270 of 2,581,359
# processing file # 774,405 of 2,581,359
# processing file # 1,032,540 of 2,581,359
# processing file # 1,290,675 of 2,581,359
# processing file # 1,548,810 of 2,581,359
# processing file # 1,806,945 of 2,581,359
# processing file # 2,065,080 of 2,581,359
# processing file # 2,323,215 of 2,581,359
# processing file # 2,581,350 of 2,581,359
# 2021-03-20 22:08:55
# DONE
# CPU times: user 47.6 s, sys: 47.1 s, total: 1min 34s
# Wall time: 1min 48s

# %%
time2 = time.time()
elapsed = time2-time1
print(f"Elapsed seconds = {elapsed:.3f}")
# Out:
# Elapsed seconds = 137.920
