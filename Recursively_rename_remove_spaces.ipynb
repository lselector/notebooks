# %% [markdown]
# ## Recursively remove spaces from file names
#
# If you use this common command:
#
# ``` find ./ ...    | xargs grep  ... ```
#
# it will break on names consisting of several words separated by spaces, because it will try to treat each word as a separate file name. You can go around this problem using options to use ASCII NUL character instead of space to end (separate) the filenames
# ```
#   -print0 option in find,
#   -0      option in xargs
# ```
# for example:
#
# ``` find ./ -type f -print0 | xargs -0 ls -1 ```
#
# Or you can simply clean the names by substituting
# spaces by underscores using code below

# %%
import sys, os, glob, subprocess, time

# %%
# provide absolute path under which you want to clean out spaces from names

# MYDIR = "/some/path"

HOME = os.environ['HOME']
MYDIR = HOME + "/"
print(MYDIR)
if not os.path.isdir(MYDIR):
    print("ERROR - no such directory")
# Out:
# /Users/levselector/

# %%
# %%time
time1 = time.time()
# Clean directories' names.
# We need to do it layer by layer.
# So repeat this cell several times until there is no output.
dirs = glob.glob(MYDIR+"/**/", recursive=True)
for mydir in dirs:
    if "/Users/levselector/Library" in mydir:
        continue
    if not os.path.isdir(mydir):
        continue
    if " " not in mydir:
        continue
    mydir2 = mydir.replace(" ","_")
    print(f"renaming: {mydir} => {mydir2}")
    os.rename(mydir, mydir2)
print("DONE")
# Out:
# DONE
# CPU times: user 8.64 s, sys: 14.1 s, total: 22.8 s
# Wall time: 25.7 s

# %%
# %%time
# Now rename files to remove spaces.
# Run it twice. On second run there should be no output.
files = glob.glob(MYDIR+"/**", recursive=True)
for myfile in files:
    if "/Users/levselector/Library" in myfile:
        continue
    if not os.path.isfile(myfile):
        continue
    if " " not in myfile:
        continue
    myfile2 = myfile.replace(" ","_")
    print(f"renaming: {myfile} => {myfile2}")
    os.rename(myfile, myfile2)
print("DONE")
# Out:
# DONE
# CPU times: user 42.8 s, sys: 42.1 s, total: 1min 24s
# Wall time: 1min 38s

# %%
# %%time
# Now rename files to remove quotes.
# Run it twice. On second run there should be no output.
files = glob.glob(MYDIR+"/**", recursive=True)
for myfile in files:
    if "/Users/levselector/Library" in myfile:
        continue
    if not os.path.isfile(myfile):
        continue
    if "'" not in myfile:
        continue
    myfile2 = myfile.replace("'","_")
    print(f"renaming: {myfile} => {myfile2}")
    os.rename(myfile, myfile2)
print("DONE")
# Out:
# DONE
# CPU times: user 42.9 s, sys: 44.2 s, total: 1min 27s
# Wall time: 1min 38s

# %%
# %%time
# Now rename files to remove double quotes.
# Run it twice. On second run there should be no output.
files = glob.glob(MYDIR+"/**", recursive=True)
for myfile in files:
    if "/Users/levselector/Library" in myfile:
        continue
    if not os.path.isfile(myfile):
        continue
    if '"' not in myfile:
        continue
    myfile2 = myfile.replace('"',"_")
    print(f"renaming: {myfile} => {myfile2}")
    os.rename(myfile, myfile2)
print("DONE")
# Out:
# DONE
# CPU times: user 42.7 s, sys: 44.9 s, total: 1min 27s
# Wall time: 1min 40s

# %%
# %%time
# Now rename files to remove "&" symbol
# Run it twice. On second run there should be no output.
files = glob.glob(MYDIR+"/**", recursive=True)
for myfile in files:
    if "/Users/levselector/Library" in myfile:
        continue
    if not os.path.isfile(myfile):
        continue
    if '&' not in myfile:
        continue
    myfile2 = myfile.replace('&',"_")
    print(f"renaming: {myfile} => {myfile2}")
    os.rename(myfile, myfile2)
print("DONE")
# Out:
# DONE
# CPU times: user 42.8 s, sys: 45.4 s, total: 1min 28s
# Wall time: 1min 42s

# %%
time2 = time.time()
elapsed = time2-time1
print(f"Elapsed seconds = {elapsed:.3f}")
# Out:
# Elapsed seconds = 424.709
