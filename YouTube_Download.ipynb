# %% [markdown]
# ### It is easy to download videos from YouTube
#
# Using module __pytube__ - https://pypi.org/project/pytube/

# %%
from pytube import YouTube

# %%
# Let's download first four minutes of Spies in Disguise 
url = "www.youtube.com/watch?v=vwwM3MixzMQ"
yt = YouTube(url)

# %%
# Lets get a list of all available streams
# (different video quality) 
for idx, stream in enumerate(yt.streams):
    print(f"{idx} - {str(stream)}")
# Out:
# 0 - <Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">
# 1 - <Stream: itag="22" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.64001F" acodec="mp4a.40.2" progressive="True" type="video">
# 2 - <Stream: itag="137" mime_type="video/mp4" res="1080p" fps="30fps" vcodec="avc1.640028" progressive="False" type="video">
# 3 - <Stream: itag="248" mime_type="video/webm" res="1080p" fps="30fps" vcodec="vp9" progressive="False" type="video">
# 4 - <Stream: itag="399" mime_type="video/mp4" res="1080p" fps="60fps" vcodec="av01.0.08M.08" progressive="False" type="video">
# 5 - <Stream: itag="136" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.4d401f" progressive="False" type="video">
# 6 - <Stream: itag="247" mime_type="video/webm" res="720p" fps="30fps" vcodec="vp9" progressive="False" type="video">
# ...

# %%
# OK, lets download the very first stream (with index = 0)
idx = 0
stream = yt.streams[idx]
print("Downloading ...")
#  output_file = stream.download(
#                 output_path="/some/path", 
#                 filename="mytest.mp4")
output_file = stream.download() # downloads orig. name in current working directory
print(output_file)
print("Done")
# Out:
# ...
# /Users/levselector/test/First 4 Minutes of Spies In Disguise.mp4
# Done
