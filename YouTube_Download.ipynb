# %% [markdown]
# ### It is easy to download videos from YouTube
#
# Using module __pytube__ - https://pypi.org/project/pytube/
#
# See docs here: - https://python-pytube.readthedocs.io/en/latest/

# %%
# !pip install pytube
from pytube import YouTube

# %%
# Let's download first four minutes of Spies in Disguise 
# url = "www.youtube.com/watch?v=vwwM3MixzMQ" # Spies in Disguise 
# url = "https://www.youtube.com/watch?v=LX-S1CX1HUI" # how to use GIMP
# url = "https://www.youtube.com/watch?v=rLWXlc1BW-I" # OpenShot tutorial
# url = "https://www.youtube.com/watch?v=x1g4Hhx_mK0" # Firebolt POC
url = "https://www.youtube.com/watch?v=8PEnxC-W-GM"  
yt = YouTube(url)

# %%
# Lets get a list of all available streams
# (different video quality) 
for idx, stream in enumerate(yt.streams):
    print(f"{idx} - {str(stream)}")
# Out:
# 0 - <Stream: itag="18" mime_type="video/mp4" res="360p" fps="25fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">
# 1 - <Stream: itag="22" mime_type="video/mp4" res="720p" fps="25fps" vcodec="avc1.64001F" acodec="mp4a.40.2" progressive="True" type="video">
# 2 - <Stream: itag="137" mime_type="video/mp4" res="1080p" fps="25fps" vcodec="avc1.640028" progressive="False" type="video">
# 3 - <Stream: itag="136" mime_type="video/mp4" res="720p" fps="25fps" vcodec="avc1.64001f" progressive="False" type="video">
# 4 - <Stream: itag="134" mime_type="video/mp4" res="360p" fps="25fps" vcodec="avc1.4d401e" progressive="False" type="video">
# 5 - <Stream: itag="160" mime_type="video/mp4" res="144p" fps="25fps" vcodec="avc1.4d400c" progressive="False" type="video">
# 6 - <Stream: itag="139" mime_type="audio/mp4" abr="48kbps" acodec="mp4a.40.5" progressive="False" type="audio">
# 7 - <Stream: itag="140" mime_type="audio/mp4" abr="128kbps" acodec="mp4a.40.2" progressive="False" type="audio">
# 8 - <Stream: itag="251" mime_type="audio/webm" abr="160kbps" acodec="opus" progressive="False" type="audio">

# %%
# Enter the stream number which we want:
idx = 2
stream = yt.streams[idx]
print("Downloading ...")
#  output_file = stream.download(
#                 output_path="/some/path", 
#                 filename="mytest.mp4")
output_file = stream.download() # downloads orig. name in current working directory
print(output_file)
print("Done")
# Out:
# Downloading ...
# /Users/levselector/Documents/GitHub/notebooks/Bone grafts barriers growth factors and growth enhancers -Dr Robert Horowitz.mp4
# Done

# %%
# Alternatively you can do this:
#     https://python-pytube.readthedocs.io/en/latest/

url = 'https://youtu.be/9bZkp7q19f0'

YouTube(url).streams.first().download()
# Out:
# '/Users/levselector/Documents/GitHub/notebooks/PSY - GANGNAM STYLE(강남스타일) MV.3gpp'

# %%
# or you can automate stream selection
# by chaining the criteria

yt = YouTube(url)
(yt.streams
    . filter(progressive=True, file_extension='mp4')
    . order_by('resolution')
    . desc()
    . first()
    . download())
# Out:
# '/Users/levselector/Documents/GitHub/notebooks/PSY - GANGNAM STYLE(강남스타일) MV.mp4'

# %%
# !/bin/ls -a1F PSY*
# Out:
# PSY - GANGNAM STYLE(강남스타일) MV.3gpp
# PSY - GANGNAM STYLE(강남스타일) MV.mp4
