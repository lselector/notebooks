# %% [markdown]
# ## Template Notebook
#
# <pre>
# Common template to start
# </pre>

# %%
import sys, os, time, glob, re, pickle, math
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
from util_jupyter import *
# from util_models import *
from mybag import *
run_step = 0
nb_time_start = time.time()
# ----------------------------------
def print_date_time():
    print(dt.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
plt
x = [1,2,3,4,5]
y = [1,2,1,3,1]
plt.plot(x,y,color="red")
# plt.plot(x,z,color="green")
plt.show(); # semicolon needed to remove text output on top

# %%
x = [1,2,3,4,5]
actual = [1,2,1,3,1]
predic = [2,3,1.5,2,2]
myval = 0.05

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(5,2))
plt.xticks(rotation='45', ha='right')
ax.plot(x,actual,color="red", label='actual')
ax.plot(x,predic,color="green", label='predicted')
ax.legend(prop={"size": 10}, loc="best")
ax.set_title(f"Actual vs Predicted, wape = {myval:.2f}", fontsize= 10)
plt.show(); # semicolon needed to remove text output on top
# fig.savefig(f"{fname}.png") # we can save picture to image file
